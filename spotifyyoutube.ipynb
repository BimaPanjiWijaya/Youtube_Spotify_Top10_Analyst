# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import plotly.express as px

# %%
df=pd.read_csv("Spotify_Youtube.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20718 non-null  int64
#  1   Artist            20718 non-null  object
#  2   Url_spotify       20718 non-null  object
#  3   Track             20718 non-null  object
#  4   Album             20718 non-null  object
#  5   Album_type        20718 non-null  object
#  6   Uri               20718 non-null  object
#  7   Danceability      20716 non-null  float64
#  8   Energy            20716 non-null  float64
#  9   Key               20716 non-null  float64
#  10  Loudness          20716 non-null  float64
#  11  Speechiness       20716 non-null  float64
#  12  Acousticness      20716 non-null  float64
#  13  Instrumentalness  20716 non-null  float64
#  14  Liveness          20716 non-null  float64
#  15  Valence           20716 non-null  float64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  Danceability        Energy           Key      Loudness  \
# count  20718.000000  20716.000000  20716.000000  20716.000000  20716.000000
# mean   10358.500000      0.619777      0.635250      5.300348     -7.671680
# std     5980.915774      0.165272      0.214147      3.576449      4.632749
# min        0.000000      0.000000      0.000020      0.000000    -46.251000
# 25%     5179.250000      0.518000      0.507000      2.000000     -8.858000
# 50%    10358.500000      0.637000      0.666000      5.000000     -6.536000
# 75%    15537.750000      0.740250      0.798000      8.000000     -4.931000
# max    20717.000000      0.975000      1.000000     11.000000      0.920000
#
#         Speechiness  Acousticness  Instrumentalness      Liveness  \
# count  20716.000000  20716.000000      20716.000000  20716.000000
# mean       0.096456      0.291535          0.055962      0.193521
# std        0.111960      0.286299          0.193262      0.168531
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0          20718
# Artist               2079
# Url_spotify          2079
# Track               17841
# Album               11937
# Album_type              3
# Uri                 18862
# Danceability          898
# Energy               1268
# Key                    12
# Loudness             9417
# Speechiness          1303
# Acousticness         3138
# Instrumentalness     4012
# Liveness             1536
# Valence              1293
# Tempo               15024
# Duration_ms         14690
# Url_youtube         18154
# Title               18146
# Channel              6714
# Views               19245
# Likes               17939
# Comments            10485
# Description         17395
# Licensed                2
# official_video          2
# Stream              18461
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Artist', 'Url_spotify', 'Track', 'Album', 'Album_type',
#        'Uri', 'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
plt.figure(figsize=(20, 5))
color = 'pink'
b=sns.countplot(data=df, color='pink', x='Artist', order=df['Artist'].value_counts().index[:10])
b.set_xticklabels(b.get_xticklabels(), rotation=30)
plt.title("Top 10 Artist")
plt.show()

# %%
df_views = df.groupby('Artist')['Views'].sum().sort_values(ascending=False)[:10]
df_streams = df.groupby('Artist')['Stream'].sum().sort_values(ascending=False)[:10]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,6))

color = 'orange'
ax1.set_title('Top 10 Artists on YouTube')
df_views.plot(kind='bar', color='orange', ax=ax1)

color = 'yellow'
ax2.set_title('Top 10 Artists on Spotify')
df_streams.plot(kind='bar', color='yellow', ax=ax2)


ax1.set_xlabel('Artist')
ax1.set_ylabel('Views')
ax2.set_xlabel('Artist')
ax2.set_ylabel('Streams')
fig.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 5))
color='purple'
b = sns.countplot(data=df, color='purple', x='Channel', order=df['Channel'].value_counts().index[:10])
b.set_xticklabels(b.get_xticklabels(), rotation=30)
plt.title("Top 10 Channel")
plt.show()

# %%
plt.figure(figsize=(20, 5))
color='red'
b = sns.countplot(data=df, color='red', x='Album', order=df['Album'].value_counts().index[:10])
b.set_xticklabels(b.get_xticklabels(), rotation=30)
plt.title("Top 10 Album")
plt.show()

# %%
df = pd.DataFrame(df['Album_type'].value_counts()).reset_index()
df.columns = ['Type','Count']
df['Percent'] = df['Count'].apply(lambda x : x / df['Count'].sum() * 100).round(1)
_data = df['Percent'].tolist()
_keys = df['Type'].tolist()
colors = ['red','green','blue']
explode = [0.1, 0.1, 0.1]
plt.pie(_data, labels=_keys, colors=colors, explode=explode, autopct='%.0f%%')
plt.title('Comparison Album Type', fontsize=10)
plt.show()
